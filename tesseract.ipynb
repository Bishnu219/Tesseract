# %% [markdown]
# # Read Text form images with tesseract

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # simple image to read text from it

# %%
img = cv2.imread(r"C:\Users\User\Desktop\researchimage\text1.png")
plt.imshow(img)
cv2.imshow("Sample Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# The elusive
#
# BIGTEXT
#
# plugin exclusively
# captured on film

# %% [markdown]
# # read research paper text form image of it

# %%
img1 = cv2.imread(r"C:\Users\User\Desktop\researchimage\Automatic_Grape_Leaf_Diseases_Identification_via_U-3.jpg")
plt.imshow(img1)
cv2.imshow("Sample Image", img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text = pytesseract.image_to_string(img1)
print(text)
# Out:
# INFORMATION PROCESSING IN AGRICULTURE XXX (XXXX) XXX 3
#
# [Table 1 - Introduction of grape leaf dataset.
#
# Label Category Number Data No data augmentation Leaf symptoms Illustration
# augmentation
# Training Validation Test
# samples samples samples
# 1 Black rot 476 288 72 116 Appear small, See Fig. 1 first row
# brown circular lesions
# 2 Esca 552 288 72 192 Appear dark red or yellow stipes See Fig. 1 second row
# 3 Isariopsis 420 288 72 60 Appear many small rounded, See Fig. 1 third row
# leaf spot polygonal
# or irregular brown spots
# 4 Health 171 96 24 51 - See Fig. 1 fourth row
# Totalsamples 1619 960 240 419 - -
#
# Fig. 1 - The grape leaf images after data augmentation.
#
# the leaf is generally sensitive to the state of plants, whose
# shape, texture and color usually contains richer information.
#
# The raw images are divided into training dataset and test
# dataset. 360 Symptom and 120 healthy images are selected
# ...

# %% [markdown]
# # Fine tuning for better result

# %%
img5 = cv2.imread(r"C:\Users\User\Desktop\researchimage\book_page.jpg")
plt.imshow(img5)
img5 = cv2.resize(img5, None, fx=0.8, fy=0.8)
# 3. Convert image to grayscale
gray = cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)
# 4. Convert image to black and white (using adaptive threshold)
adaptive_threshold = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 85, 11)

cv2.imshow("Sample Image", adaptive_threshold)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text = pytesseract.image_to_string(adaptive_threshold)
print(text)
# Out:
# Design before you implement
#
# iculatly if the project involves designing a product or service, ensure
# have the best possible answer in the design phase before you start
# tation. Another 80/20 rule says that 20 per cent of the prob-
# plier y design project cause 80 per cent of the costs or overruns:
# 1s Wath AY ent of these critical problems arise in the design phase
# J nen expensive to correct later, requiring massive rework and
# aoe cases retooling.
# in

# %% [markdown]
# # Page segmentation modes

# %%
# There is 10 different Page segmentation modes in tesseract optical character recognition these are as follows
# 0 = Orientation and script detection (OSD) only.
# 1 = Automatic page segmentation with OSD.
# 2 = Automatic page segmentation, but no OSD, or OCR
# 3 = Fully automatic page segmentation, but no OSD. (Default)
# 4 = Assume a single column of text of variable sizes.
# 5 = Assume a single uniform block of vertically aligned text.
# 6 = Assume a single uniform block of text.
# 7 = Treat the image as a single text line.
# 8 = Treat the image as a single word.
# 9 = Treat the image as a single word in a circle.
# 10 = Treat the image as a single character.

# %%
config = "--psm 3"
text = pytesseract.image_to_string(adaptive_threshold, config=config)
print(text)
# Out:
# Design before you implement
#
# iculatly if the project involves designing a product or service, ensure
# have the best possible answer in the design phase before you start
# tation. Another 80/20 rule says that 20 per cent of the prob-
# plier y design project cause 80 per cent of the costs or overruns:
# 1s Wath AY ent of these critical problems arise in the design phase
# J nen expensive to correct later, requiring massive rework and
# aoe cases retooling.
# in
